# %%
import mahotas as mh

# %%
import numpy as np

# %%
image=mh.imread('正装照.png')

# %%
image=image-image.mean()

# %%
# %matplotlib inline

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(image)

# %%
plt.show()

# %%
image=mh.colors.rgb2gray(image,dtype=np.uint8)

# %%
plt.imshow(image)

# %%
plt.gray()

# %%
thresh=mh.thresholding.otsu(image)

# %%
plt.imshow(image>thresh)

# %%
otsubin=(image<=thresh)

# %%
otsubin=mh.close(otsubin,np.ones((15,15)))

# %%
plt.imshow(otsubin)

# %%
thresh=mh.thresholding.rc(image)

# %%
thresh
# Out:
# 122.71322441474804

# %%
im8=mh.gaussian_filter(image,8)

# %%
plt.imshow(im8)

# %%
im=mh.imread('正装照.png',as_grey=True)

# %%
salt=np.random.random(im.shape)>.975

# %%
pepper=np.random.random(im.shape)>.975

# %%
im=mh.stretch(im)
